# %% [markdown]
# <a href="https://colab.research.google.com/github/meyush0/Play-Store-App-Review-Analysis/blob/main/EDA_Play_Store_App_Review_Analysis_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
# # Play Store App Review Analysis Capstone Project

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Ayush Singh.

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ### Application distribution platform, for example, Play Store gets overwhelmed with millions of new applications being launched on the platform regularly. Lots of designers and developers work on it to make an app successful on the Play Store. In this highly competitive world, it is an immense challenge for a developer to know whether they are focusing on the right path to make their app successful on the platform.
#
# ### To launch themselves successfully and create an identity for themselves in this oversaturated market, they need to ensure that majority of the essential factors are incorporated while designing and developing an app that would play an important role in customer's decision-making process. However, the lack of a clear understanding of the inner working and dynamic of popular app markets impacts both the developers and users.
#
# ### The main objective of this exploratory data analysis project is to understand customer demands better and thus help developers to popularize their product on the Play Store.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/meyush0/Play-Store-App-Review-Analysis

# %% [markdown]
# # **Objective** : -

# %% [markdown]
# ###  An MNC plans to debut into the Android application by developing a mobile application on the play store platoform. They approaced us "Data Diggers" to help with building their technical know how about building a good android application. They wanted us to study current trends and insights of Play Store.
#
# ### We were given with two datasets i.e., Play Store & User Reviews. Before jumping into the data's provided, let me first explain you about the EDA analysis.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ### 1. Top categories on Google Playstore?
# ### 2. Which category of Apps from the Content Rating column are found more on playstore?
# ### 3. Distribution of the ratings of the apps?
# ### 4. what portion of the apps in playstore are paid and free ?
# ### 5  Which category App's have most number of installs?
# ### 6. What are the Top 10 installed apps in any category?
# ### 7. Which are the top 10 expensive Apps in playstore?
# ### 8. Which are the Apps with highest number of reviews?
# ### 9. What are the count of Apps in different genres?

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Load data-set as dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
df=pd.read_csv("/content/drive/MyDrive/_EDA_Project(capstone)/Play Store Data.csv")

# %%
#loading of review data set
app_reviews = pd.read_csv("/content/drive/MyDrive/_EDA_Project(capstone)/User Reviews.csv")

# %%
#Making a copy.
play_store_data = df.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %% [markdown]
# ### Findings
#
# #### play_store dataframe has 10841 rows and 13 columns. The 13 columns are identified as below:
#
# #### **App - It tells us about the name of the application.
#
# #### **Category - It tells us about the category to which an application belongs.
#
# #### **Rating - It tells us about the ratings given by the users for a specific application.
#
# #### **Reviews - It tells us about the total number of users who have given a review for the application.
#
# #### **Size - It tells us about the size being occupied the application on the mobile phone.
#
# #### **Installs - It tells us about the total number of installs/downloads for an application.
#
# #### **Type - It tells us whether the application is free or a paid one.
#
# #### **Price - It tells us about the price of the application.
#
# #### **Content_Rating - It tells us about the target audience for the application.
#
# #### **Genres - It tells us about the various other categories to which an application can belong.
#
# #### **Last_Updated - It tells us about the when the application was updated.
#
# #### **Current_Ver - It tells us about the current version of the application.
#
# #### **Android_Ver - It tells us about the android version which can support the application on its platform.

# %%
app_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# #### *App - It tells us about the name of the application.
#
# #### *Translated_Review - It tells us about what the users feedback is about the application.
#
# #### *Sentiment - It tells us about a view or opinion of the user w.r.t. the application.
#
# #### *Sentiment_Polarity - Sentiment polarity for an element defines the orientation of the expressed sentiment, i.e., it determines if the text expresses the positive, negative or neutral sentiment of the user about the application.
#
# #### *Sentiment_Subjectivity - It refers to the text that contains text which is usually expressed by a human having typical moods, emotions, and feelings. Mostly it is a public opinion and not a factual information.

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print("Number of rows:",play_store_data.shape[0] )
print("Number of columns:", play_store_data.shape[1])
# Out:
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
play_store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#finding the data types
play_store_data.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#top values of the dataset
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
#last values of the dataset
play_store_data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
#describing all variables (statistical information of the data)
play_store_data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
#user review datasets info
app_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
app_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
play_store_data.boxplot()
# Out:
# <Axes: >

# %%
 play_store_data.hist()
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

num_duplicates = play_store_data.duplicated().sum()
print("Number of duplicate :", num_duplicates)
# Out:
# Number of duplicate : 483

# %% [markdown]
# #### Missing Values/Null Values

# %% [markdown]
# Count the number of missing values in the dataframe

# %%
play_store_data.isnull()
# Out:
#          App  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0      False     False   False    False  False     False  False  False
# 1      False     False   False    False  False     False  False  False
# 2      False     False   False    False  False     False  False  False
# 3      False     False   False    False  False     False  False  False
# 4      False     False   False    False  False     False  False  False
# ...      ...       ...     ...      ...    ...       ...    ...    ...
# 10836  False     False   False    False  False     False  False  False
# 10837  False     False   False    False  False     False  False  False
# 10838  False     False    True    False  False     False  False  False
# 10839  False     False   False    False  False     False  False  False
# 10840  False     False   False    False  False     False  False  False
#
#        Content Rating  Genres  Last Updated  Current Ver  Android Ver
# ...

# %%
play_store_data.isnull().any()
# Out:
# App               False
# Category          False
# Rating             True
# Reviews           False
# Size              False
# Installs          False
# Type               True
# Price             False
# Content Rating     True
# Genres            False
# Last Updated      False
# Current Ver        True
# Android Ver        True
# dtype: bool

# %% [markdown]
# ### Checking how many ratings are more than 5

# %%
play_store_data[play_store_data.Rating > 5]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating     Genres Last Updated  \
# 10472  1,000+     Free    0  Everyone            NaN  11-Feb-18       1.0.19
#
#       Current Ver Android Ver
# 10472  4.0 and up         NaN

# %%
#droping row which have outliers
play_store_data.drop([10472],inplace = True)

# %%
play_store_data.loc[10470:10475]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
# 10475         Wi-Fi Visualizer            TOOLS     3.9     132  2.6M
#
#           Installs  Type Price Content Rating           Genres Last Updated  \
# 10470      10,000+  Free     0       Everyone    Communication    10-Feb-17
# 10471     100,000+  Free     0       Everyone  Personalization     5-Aug-14
# 10473  10,000,000+  Free     0       Everyone            Tools     7-Aug-18
# 10474       1,000+  Free     0       Everyone    Communication    21-Nov-14
# 10475      50,000+  Free     0       Everyone            Tools    17-May-17
#
#       Current Ver   Android Ver
# 10470         0.1    2.3 and up
# ...

# %%
play_store_data.boxplot()
# Out:
# <Axes: >

# %%
play_store_data.hist()
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)

# %% [markdown]
# When in any column 90% of data is missing then we should ignore that column, But this is not the case in this data,but still for a check.

# %%
threshold = len(play_store_data) * 0.1
threshold
# Out:
# 1084.0

# %%
play_store_data.dropna(thresh=threshold,axis=1,inplace=True)

# %% [markdown]
# ## *Does the dataframe contains any Nan value?*

# %%
play_store_data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Yes, the play_store_data dataframe contains NaN values.
#
# You can see this from the output of play_store_data.isnull().sum(), which shows the number of missing values for each column. The Rating column has 1474 missing values, the Type column has 1 missing value, the Current Ver column has 8 missing values, and the Android Ver column has 2 missing values.

# %%
play_store_data.shape
# Out:
# (10840, 13)

# %% [markdown]
# ### Data Manipulation
#
#
# Filling the Null values with the appropriate values using aggregate functions such as Mean,Median,Mode

# %%
# Defining the function to fill the null values with the median.
def data_median(series):
    return series.fillna(series.median())

# %%
play_store_data.Rating = play_store_data['Rating'].transform(data_median)

# %%
# Count the number of values in each column
play_store_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# Now, we have treated Rating  with median values
#
#
# where some categorical variables such as "Type","Current Ver","Android Ver"  also have null values we treat it with mode values

# %%
# Mode of categorical values
print(play_store_data['Type'].mode())
print(play_store_data['Current Ver'].mode())
print(play_store_data['Android Ver'].mode())
# Out:
# 0    Free
# Name: Type, dtype: object
# 0    Varies with device
# Name: Current Ver, dtype: object
# 0    4.1 and up
# Name: Android Ver, dtype: object

# %%
# Filling the missing categorical values with Mode
play_store_data['Type'].fillna(str(play_store_data['Type'].mode().values[0]),inplace=True)
play_store_data['Current Ver'].fillna(str(play_store_data['Current Ver'].mode().values[0]),inplace=True)
play_store_data['Android Ver'].fillna(str(play_store_data['Android Ver'].mode().values[0]),inplace=True)

# %%
# Counting the number of null values in each column
play_store_data.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
play_store_data.head(7)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
# ...

# %%
# Converting Price,Size and installs

#we create a function which convert Mega-bite to kilo-byte

def convrt(Size):
    if Size =='Varies with device':
        return np.nan

    elif 'M' in Size:
        Size=Size.replace('M','000')
        return eval(Size)

    elif 'k' in Size:
        Size=Size.replace('k','')
        return eval(Size)

# %%
#applying the convte function to convert in into kilo byte
play_store_data['Size']= play_store_data['Size'].apply(convrt)
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type Price Content Rating  \
# 0     159  19000.0      10,000+  Free     0       Everyone
# 1     967  14000.0     500,000+  Free     0       Everyone
# 2   87510      8.7   5,000,000+  Free     0       Everyone
# 3  215644  25000.0  50,000,000+  Free     0           Teen
# 4     967      2.8     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
# To remove the '+' and ',' from the number of install

# we make a function and apply it to the dataset

def removing_plus_comma(installs):
    if isinstance(installs, float):
        return installs
    elif '+' in installs:
        installs = installs.replace('+','')
    if ',' in installs:
        installs = installs.replace(',','')
    return installs

# %%
play_store_data['Installs']= play_store_data['Installs'].apply(removing_plus_comma)
play_store_data['Installs']=play_store_data['Installs'].astype(float)
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size    Installs  Type Price Content Rating  \
# 0     159  19000.0     10000.0  Free     0       Everyone
# 1     967  14000.0    500000.0  Free     0       Everyone
# 2   87510      8.7   5000000.0  Free     0       Everyone
# 3  215644  25000.0  50000000.0  Free     0           Teen
# 4     967      2.8    100000.0  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
#converting $ to " " and make it in float
play_store_data['Price'] = play_store_data['Price'].str.replace('$', '').str.strip()
play_store_data['Price'] = play_store_data['Price'].astype(float)

# %%
# making Last Updated in proper format
play_store_data['Last Updated']

#changing date format of 'Last Updated'
play_store_data['Last Updated'] = pd.to_datetime(play_store_data['Last Updated'])

# %%
play_store_data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size    Installs  Type  Price Content Rating  \
# 0     159  19000.0     10000.0  Free    0.0       Everyone
# 1     967  14000.0    500000.0  Free    0.0       Everyone
# 2   87510      8.7   5000000.0  Free    0.0       Everyone
# 3  215644  25000.0  50000000.0  Free    0.0           Teen
# 4     967      2.8    100000.0  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# ...

# %%
play_store_data.describe()
# Out:
#              Rating           Size      Installs         Price
# count  10840.000000    9145.000000  1.084000e+04  10840.000000
# mean       4.206476   19579.419913  1.546434e+07      1.027368
# std        0.480342   24042.062020  8.502936e+07     15.949703
# min        1.000000       1.000000  0.000000e+00      0.000000
# 25%        4.100000       5.600000  1.000000e+03      0.000000
# 50%        4.300000   13000.000000  1.000000e+05      0.000000
# 75%        4.500000   30000.000000  5.000000e+06      0.000000
# max        5.000000  100000.000000  1.000000e+09    400.000000

# %%
play_store_data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# it contains information about various mobile applications on Google Play Store. The dataset contains 10,841 entries (or rows) with 13 columns. The columns include information such as the name of the app, category, rating, number of reviews, size, installation count, price, content rating, genres, and version information for the app.
#
# The data types for the columns include one float column and twelve object columns. There are some missing values in the dataset as well.
#
# There are 483 duplicate rows in the dataset and also contains some missing values in columns Rating, Current Ver etc

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
play_store_data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# the variables are fre from all the unnessary containts

# %%
#dataset describe
print(play_store_data.describe())
# Out:
#              Rating           Size      Installs         Price
# count  10840.000000    9145.000000  1.084000e+04  10840.000000
# mean       4.206476   19579.419913  1.546434e+07      1.027368
# std        0.480342   24042.062020  8.502936e+07     15.949703
# min        1.000000       1.000000  0.000000e+00      0.000000
# 25%        4.100000       5.600000  1.000000e+03      0.000000
# 50%        4.300000   13000.000000  1.000000e+05      0.000000
# 75%        4.500000   30000.000000  5.000000e+06      0.000000
# max        5.000000  100000.000000  1.000000e+09    400.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset contains 10,841 entries (or rows) with 13 columns. The columns include information such as the name of the app, category, rating, number of reviews, size, installation count, price, content rating, genres, and version information for the app.
#
# The data types for the columns include one float column and twelve object columns. There are some missing values in the dataset as well where we also cheak variables one by one and treat them

# %% [markdown]
# ### Check Unique Values for each variable.?

# %% [markdown]
# ### App

# %%
play_store_data['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %% [markdown]
# ### Rating

# %%
play_store_data['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
play_store_data['Rating'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Reviews

# %%
play_store_data['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
play_store_data['Reviews'] = play_store_data['Reviews'].astype(float)
play_store_data['Reviews'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Size

# %%
play_store_data['Size'].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+00, 2.50e+04, 2.80e+00, 5.60e+00,
#        2.90e+04, 3.30e+04, 3.10e+00, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+00, 5.50e+00, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+00, 7.00e+00, 2.30e+04, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+04, 2.40e+04,      nan,
#        9.40e+00, 1.50e+04, 1.00e+04, 1.20e+00, 2.60e+04, 8.00e+00,
#        7.90e+00, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+04, 2.50e+00,
#        1.60e+04, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+04,
#        3.20e+04, 5.40e+00, 1.80e+04, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+04, 9.00e+00, 6.70e+00, 3.00e+04, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+04, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+04, 7.30e+04, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
play_store_data['Size'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Installs

# %%
play_store_data['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %%
play_store_data['Installs'] = play_store_data.Installs.replace("Free",np.nan)
play_store_data['Installs'].dtype
# Out:
# dtype('float64')

# %%
#The resulting modified 'play_store_data' dataframe contains the updated 'Installs' column with numeric values.
play_store_data['Installs'] = pd.to_numeric(play_store_data['Installs'])

# %% [markdown]
# ### Price

# %%
play_store_data['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
play_store_data['Price'] = pd.to_numeric(play_store_data['Price'])

# %%
play_store_data['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Last Updated

# %%
play_store_data['Last Updated'].unique()
# Out:
# array(['2018-01-07T00:00:00.000000000', '2018-01-15T00:00:00.000000000',
#        '2018-08-01T00:00:00.000000000', ...,
#        '2014-01-20T00:00:00.000000000', '2014-02-16T00:00:00.000000000',
#        '2014-03-23T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
play_store_data['Last Updated']=pd.to_datetime(play_store_data['Last Updated'])
play_store_data['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
play_store_data.describe()
# Out:
#              Rating       Reviews           Size      Installs         Price
# count  10840.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean       4.206476  4.441529e+05   19579.419913  1.546434e+07      1.027368
# std        0.480342  2.927761e+06   24042.062020  8.502936e+07     15.949703
# min        1.000000  0.000000e+00       1.000000  0.000000e+00      0.000000
# 25%        4.100000  3.800000e+01       5.600000  1.000000e+03      0.000000
# 50%        4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%        4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max        5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#merging both data on 'App'
app_review_df = play_store_data.merge(app_reviews, on='App')
app_review_df
# Out:
#                                  App        Category  Rating   Reviews  \
# 0                Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 1                Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 2                Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 3                Coloring book moana  ART_AND_DESIGN     3.9     967.0
# 4                Coloring book moana  ART_AND_DESIGN     3.9     967.0
# ...                              ...             ...     ...       ...
# 122657  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 122658  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 122659  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 122660  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
# 122661  A+ Gallery - Photos & Videos     PHOTOGRAPHY     4.5  223941.0
#
#            Size    Installs  Type  Price Content Rating  \
# 0       14000.0    500000.0  Free    0.0       Everyone
# ...

# %% [markdown]
# we have three new columns i.e.. Sentiment, Sentiment Polarity and Sentiment Subjectivity.
#
# Sentiment basically determines the attitude or the emotion of the reviewer, i.e., whether it is positive or negative or neutral.
#
# Sentiment Polarity is a float which lies in the range of [-1,1] where 1 means positive statement and -1 means a negative statement.
#
# Sentiment Subjectivity generally refer to personal opinion, emotion or judgment, which lies in the range of [0,1].

# %%
app_review_df.shape
# Out:
# (122662, 17)

# %%
app_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
app_reviews.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
app_review_df.describe()
# Out:
#               Rating       Reviews          Size      Installs          Price  \
# count  122662.000000  1.226620e+05  75432.000000  1.226620e+05  122662.000000
# mean        4.322397  2.243249e+06  33495.122504  7.304089e+07       0.128265
# std         0.284720  6.324819e+06  28753.068769  1.896831e+08       1.563680
# min         2.500000  1.000000e+01      1.200000  1.000000e+03       0.000000
# 25%         4.200000  2.752400e+04  11000.000000  1.000000e+06       0.000000
# 50%         4.400000  1.598720e+05  25000.000000  1.000000e+07       0.000000
# 75%         4.500000  1.500999e+06  53000.000000  1.000000e+08       0.000000
# max         4.900000  7.815831e+07  99000.000000  1.000000e+09      33.990000
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        72615.000000            72615.000000
# mean             0.157320                0.494162
# std              0.332652                0.240144
# min             -1.000000                0.000000
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Handling missing values in the 'Rating', 'Type', 'Current Ver', 'Android Ver', 'Size', 'Installs', and 'Price' columns by filling them with appropriate values.
#
# Converting the data types of columns 'Size', 'Installs', and 'Price' to a numerical data type.
#
# Cleaning the 'Price' column by removing the '$' symbol.
#
# Cleaning the 'Size' column by converting it from Mega-bytes to kilo-bytes.
#
# Cleaning the 'Installs' column by removing the '+' and ',' characters.
#
# Changing the data type of the 'Last Updated' column to a date-time format.
#
#
# Firstly, by cleaning and converting the 'Size' column from Mega-bytes to kilo-bytes, we can now analyze the impact of app size on the number of installs. We can investigate if apps with smaller sizes are more popular and have higher install counts than apps with larger sizes.
#
# Secondly, by removing the '+' and ',' characters from the 'Installs' column and converting it to a numerical data type, we can analyze the relationship between app installs and other factors such as app rating, price, size, category, and more.
#
# Lastly, by converting the 'Price' column to a numerical data type by removing the '$' symbol, we can analyze the relationship between app pricing and other factors such as installs, ratings, and category. We can investigate if free apps receive more installs and have higher ratings than paid apps, or if there is no clear relationship between pricing and app performance.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
#Creating category for categorical data

# %%
grp = play_store_data.groupby('Category')
x = grp['Rating'].agg(np.mean)
y = grp['Price'].agg(np.sum)
z = grp['Reviews'].agg(np.mean)
print(x)
print(y)
print(z)
# Out:
# Category
# ART_AND_DESIGN         4.355385
# AUTO_AND_VEHICLES      4.205882
# BEAUTY                 4.283019
# BOOKS_AND_REFERENCE    4.335498
# BUSINESS               4.182391
# COMICS                 4.160000
# COMMUNICATION          4.180103
# DATING                 4.025641
# EDUCATION              4.388462
# ENTERTAINMENT          4.126174
# EVENTS                 4.395313
# FAMILY                 4.204564
# FINANCE                4.151639
# FOOD_AND_DRINK         4.185827
# GAME                   4.286888
# HEALTH_AND_FITNESS     4.280059
# HOUSE_AND_HOME         4.211364
# LIBRARIES_AND_DEMO     4.207059
# LIFESTYLE              4.131414
# MAPS_AND_NAVIGATION    4.075182
# MEDICAL                4.216199
# NEWS_AND_MAGAZINES     4.161837
# PARENTING              4.300000
# PERSONALIZATION        4.328827
# PHOTOGRAPHY            4.197910
# PRODUCTIVITY           4.226651
# SHOPPING               4.263077
# SOCIAL                 4.261017
# SPORTS                 4.236458
# ...

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize=(16,5))
plt.plot(x,'ro')
plt.xticks(rotation = 90)
plt.title('Category wise Rating')
plt.xlabel('Categories-->')
plt.ylabel('Rating-->')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  line chart in this context is to visually represent the trend or changes in ratings for different categories over a continuous. Range Trend Analysis A line chart can provide a clear visual representation of how ratings change over time or a continuous variable .The line chart allows for a quick comparison of ratings between categories. : Line charts are compact and efficient at representing trends over time or a continuous range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Education, Events, and Books & Reference have the highest ratings, while Dating and Maps & Navigation have lower ratings. Games are well-received, and Health & Fitness, Personalization, and Entertainment are also popular. The Tools category has a relatively lower rating. These insights help understand user satisfaction and category performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# The gained insights can positively impact businesses by identifying opportunities for development, improving user satisfaction, gaining a competitive edge, enabling targeted marketing, and guiding product enhancements. By understanding categories with high ratings, businesses can align their offerings with user preferences, enhance the user experience, and drive revenue growth. Conversely, insights from lower-rated categories can inform improvements to address user concerns and increase overall satisfaction, leading to a positive business impact.

# %%
#category vise price
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='g')
plt.xticks(rotation=90)
plt.title('Category wise Price')
plt.xlabel('Categories-->')
plt.ylabel('Price-->')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The advantage of using a line chart to visualize category-wise prices is the ability to analyze trends, compare price levels, identify outliers, and provide a compact representation of price distribution. This aids in pricing strategies, market analysis, and decision-making for product offerings and competitiveness.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  data include higher ratings for Events, Education, and Books & Reference, indicating user satisfaction. Auto & Vehicles, Finance, and Lifestyle have higher prices, while Beauty, Comics, and House & Home have lower prices. Some categories have an extremely high number of reviews, suggesting their popularity and potential user engagement. These insights can inform business decisions and strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the gained insights can create a positive business impact. They enable businesses to enhance user satisfaction, optimize pricing strategies, identify market opportunities, drive product development, and implement targeted marketing. By aligning with user preferences, improving offerings, and making informed decisions, businesses can boost sales, customer loyalty, and overall success in the market.

# %%
#subplot
f,(ax1,ax2,ax3) = plt.subplots(ncols=3,sharey=False)
sns.distplot(play_store_data['Rating'],hist=True,color='b',ax=ax1)
sns.distplot(play_store_data['Reviews'],hist=True,color='r',ax=ax2)
sns.distplot(play_store_data['Price'],hist=True,color='g',ax=ax3)
f.set_size_inches(15, 5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# Subplots offer advantages such as easy visual comparison, efficient use of space, contextual understanding, insights from comparison, and effective storytelling. They enhance data exploration, facilitate comprehensive analysis, and enable efficient communication of information in a compact and organized manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
# Insights from the data include higher ratings for Education, Events, and Books & Reference categories, while Dating, Maps & Navigation, and Tools have lower ratings. Pricing varies across categories, with Finance and Medical having higher prices. Some categories have extremely high numbers of reviews, indicating popularity and user engagement.

# %% [markdown]
# #### Which are the Apps with highest number of reviews?

# %%
#top ten app with highest number of reviews
highest_app_reviews = app_review_df.groupby('App')['Translated_Review'].count().sort_values(ascending=False).reset_index().head(10)
highest_app_reviews
# Out:
#                                                  App  Translated_Review
# 0                                         Bowmasters               1872
# 1                                   Candy Crush Saga               1680
# 2                     Duolingo: Learn Languages Free               1680
# 3                                         Helix Jump               1638
# 4  CBS Sports App - Scores, News, Stats & Watch Live               1536
# 5                                        8 Ball Pool               1533
# 6                                Angry Birds Classic               1365
# 7                     Calorie Counter - MyFitnessPal               1270
# 8                                   Garena Free Fire                888
# 9                                     Bubble Shooter                870

# %%
9#visualization
plt.figure(figsize=(15,9))
sns.set_style('darkgrid')
sns.barplot(x=highest_app_reviews['App'], y=highest_app_reviews['Translated_Review'], palette= "gist_earth")
plt.xticks(rotation=80)
plt.xlabel("App",fontsize=15)
plt.ylabel("Translated_Review", fontsize=15)
plt.title("App Vs Review", fontsize=25)
# Out:
# Text(0.5, 1.0, 'App Vs Review')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# bar plot, is suitable for visualizing the relationship between different apps and their corresponding translated reviews. Here are a few reasons why the bar plot is an appropriate choice:
#
# Comparison of values: A bar plot allows for an easy and effective comparison of values, making it easy to compare the magnitudes of these values.
#
# Categorical data: Since the x-axis represents the categorical variable 'App', a bar plot is a natural choice for visualizing this type of data. Each app is represented by a separate bar, allowing for clear differentiation and comparison.
#
# Clear representation of count: The bar plot clearly shows the count or frequency of translated reviews for each app. The length of each bar directly corresponds to the count, making it easy to interpret and understand the data.
#
# Ease of interpretation: Bar plots are generally easy to interpret, even for those who are not familiar with data visualization techniques. The visual representation of the data makes it easy to grasp the information quickly and draw insights from it.
#
# the choice of a bar plot for this specific scenario is driven by its ability to effectively compare and display the count of translated reviews for each app in a clear and easily interpretable manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot highlights the differences in the number of translated reviews for various apps. "Bowmasters," "Candy Crush Saga," and "Duolingo: Learn Languages Free" have the highest review counts, indicating higher user engagement and popularity. Conversely, "Bubble Shooter" and "Garena Free Fire" have relatively lower review numbers, suggesting potential areas for improvement in collecting user feedback. The plot provides a quick visual comparison of app performance, emphasizing the varying levels of user participation and indicating the apps that are likely more successful in garnering user reviews and feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights from the bar plot can potentially help create a positive business impact in the following ways:
#
# Identifying popular apps : Businesses can focus on these popular apps to capitalize on their success, potentially leading to increased revenue and customer satisfaction.
#
# Building customer trust and loyalty : By actively addressing user feedback, businesses can demonstrate their commitment to customer satisfaction, leading to increased brand loyalty and positive word-of-mouth recommendations.
#
# Improving user engagement : Businesses can implement strategies such as gamification, incentives, or targeted marketing campaigns to increase user participation and gather more reviews, ultimately improving the overall user experience.

# %% [markdown]
# ####

# %%
#visualization
plt.hist(app_review_df.loc[~app_review_df['Sentiment_Polarity'].isnull(), 'Sentiment_Polarity'])
plt.xlabel('Polarity',fontsize=15)
plt.ylabel('No.of Reviews',fontsize=15)
plt.title('Distribution of Polarity',size = 25)
# Out:
# Text(0.5, 1.0, 'Distribution of Polarity')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs offer advantages such as visual comparison, clear data representation, quantitative analysis, highlighting patterns or trends, and effective communication. They facilitate data analysis, enhance data communication, and support decision-making by providing a concise and easily interpretable visual representation of categorical or discrete data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This graph represents the the polarity are Normally distributed

# %%
g = sns.lmplot(x = 'Reviews',y='Rating',data=play_store_data)

# %% [markdown]
# if size is also one of the factors for installs, because if the App is very heavy, may be people will be hesistant and it would slow down their phone or whatsoever. Let's check if the assumption is supported by the data

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=play_store_data, x='Content Rating')
plt.xticks(rotation=80)
plt.title('Content Rating',color = 'blue',fontsize=15)
plt.show()

# %% [markdown]
# ## Percentage of Review Sentiments*

# %%
from matplotlib import pyplot as plt
counts = list(app_review_df['Sentiment'].value_counts())
labels = 'Positive Reviews', 'Negative Reviews','Neutral Reviews'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(counts, labels=labels, explode=[0, 0.05, 0.005], shadow=True, autopct="%.2f%%")
plt.title('A Pie Chart Representing Percentage of Review Sentiments', fontsize=20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# Findings:
#
# 1. Positive reviews are 63.62%
# 2. Negative reviews are 24.97%
# 3. Neutral reviews are 11.41%

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# # 1. Top categories on Google Playstore?

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
play_store_data['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
y = play_store_data['Category'].value_counts().index
x = play_store_data['Category'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.figure(figsize=(19,15))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %% [markdown]
# : So there are all total 33 categories in the dataset From the above output we can come to a conclusion that in playstore most of the apps are under Family & Game category and least are of Parenting & Beauty Category.*

# %% [markdown]
# # 2.  Which category of Apps from the Content Rating column are found more on playstore ?

# %%
x2 = play_store_data['Content Rating'].value_counts().index
y2 = play_store_data['Content Rating'].value_counts()

x2sis = []
y2sis = []
for i in range(len(x2)):
    x2sis.append(x2[i])
    y2sis.append(y2[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(x2sis,y2sis,width=0.8,color=['#15244C','#FFFF48','#292734','#EF2920','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %% [markdown]
# # 3. Distribution of the ratings of the apps?

# %%
play_store_data['Rating'].describe()
# Out:
# count    10840.000000
# mean         4.206476
# std          0.480342
# min          1.000000
# 25%          4.100000
# 50%          4.300000
# 75%          4.500000
# max          5.000000
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(15,9))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(play_store_data.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating',size = 20);

# %% [markdown]
# #  4. what portion of the apps in playstore are paid and free ?

# %%
plt.figure(figsize=(10,10))
labels = play_store_data['Type'].value_counts(sort = True).index
sizes = play_store_data['Type'].value_counts(sort = True)
colors = ["orange","lightgreen"]
explode = (0.2,0)
plt.pie(sizes, explode= None,labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=0)
plt.title('Percent of Free Vs Paid Apps in store',size = 20)
plt.show()

# %% [markdown]
# rom the above graph we can see that 92%(Approx.) of apps in google play store are free and 7%(Approx.) are paid.

# %% [markdown]
# # 5. Which category App's have most number of installs?

# %%
highest_Installs_df = play_store_data.groupby('Category')[['Installs']].sum().sort_values(by='Installs',
                                                                                          ascending=False)

# %%
highest_Installs_df.head(9)
# Out:
#                         Installs
# Category
# GAME                3.508602e+10
# COMMUNICATION       3.264728e+10
# PRODUCTIVITY        1.417609e+10
# SOCIAL              1.406987e+10
# TOOLS               1.145277e+10
# FAMILY              1.025826e+10
# PHOTOGRAPHY         1.008825e+10
# NEWS_AND_MAGAZINES  7.496318e+09
# TRAVEL_AND_LOCAL    6.868887e+09

# %%
categories = ['GAME', 'COMMUNICATION',
              'PRODUCTIVITY', 'SOCIAL',
              'TOOLS','FAMILY','PHOTOGRAPHY','NEWS_AND_MAGAZINES',
              'TRAVEL_AND_LOCAL']
installs = [3.508602e+10, 3.264728e+10,
            1.417609e+10, 1.406987e+10,
            1.145277e+10, 1.025826e+10,
           1.008825e+10,7.496318e+09,6.868887e+09]

plt.bar(categories, installs)
plt.xlabel('Category')
plt.ylabel('Number of Installs')
plt.title('App Installs by Category')

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# From the above visualization, it can be interpreted that the top categories with highest installs are Game, Communication, Productivity,Social,Tools & Family.

# %% [markdown]
# # 6. What are the Top 10 installed apps in any category?

# %%
def findtop10incategory(str):
    str = str.upper()
    top10 = play_store_data[play_store_data['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    plt.figure(figsize=(15,12))
    plt.title('Top 10 Installed Apps',size = 20);
    graph = sns.barplot(x = top10apps.App, y = top10apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
findtop10incategory('COMMUNICATION')

# %%
findtop10incategory('Sports')

# %% [markdown]
# From the above graph we can see that in the Sports category FIFA Soccer, and Dream League Soccer 2018 has the highest installs. In the same way we by passing different category names to the function, we can get the top 10 installed apps.

# %% [markdown]
# # 7. Which are the top 10 expensive Apps in playstore?

# %%
top10PaidApps = play_store_data[play_store_data['Type'] == 'Paid'].sort_values(by='Price',
                                                                               ascending=False).head(7)

# %%
colors = ['#FF9999', '#FFCC99', '#FFFF99', '#CCFF99',
          '#99FF99', '#99FFCC', '#99FFFF', '#99CCFF', '#9999FF', '#CC99FF']

plt.figure(figsize=(30, 22))
plt.pie(top10PaidApps.Installs, explode=None,
        labels=top10PaidApps.App, autopct='%1.1f%%',
        startangle=0, colors=colors)
plt.title('Top Expensive Apps Distribution', size=25)
plt.legend(top10PaidApps.App, loc="lower right",
           title="Apps", fontsize="xx-small")

plt.show()

# %% [markdown]
#  From the above graph we can interprete that the I am Rich app is the most expensive app in the google playstore.

# %% [markdown]
# # 8. Which are the Apps with highest number of reviews?

# %%
Apps_with_Highest_rev = play_store_data.sort_values(by='Reviews', ascending=False).head(20)

# %%
Apps_with_Highest_rev
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 3943                                  Facebook         SOCIAL     4.1
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 2604                                 Instagram         SOCIAL     4.5
# 2611                                 Instagram         SOCIAL     4.5
# 2545                                 Instagram         SOCIAL     4.5
# 3909                                 Instagram         SOCIAL     4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4104  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# ...

# %% [markdown]
# # 9.  What are the count of Apps in different genres?

# %%
topAppsinGenres = play_store_data['Genres'].value_counts().head(40)

# %%
x3sis = []
y3sis = []

for i in range(len(topAppsinGenres)):
    x3sis.append(topAppsinGenres.index[i])
    y3sis.append(topAppsinGenres[i])

# %%
plt.figure(figsize=(15,9))
plt.ylabel('Genres(App Count)')
plt.xlabel('Genres')
graph = sns.barplot(x=x3sis,y=y3sis,palette="deep")
graph.set_xticklabels(graph.get_xticklabels(), rotation=90, fontsize=12)
graph.set_title("Top Genres in the Playstore", fontsize = 20);

# %% [markdown]
# : From the above visualization we can see that the Highest Number of Apps found in the Tools and Entertainment genres followed by Education, Medical and many more.

# %% [markdown]
# # 10. Which are the apps that have made the highest earning?

# %%
Paid_Apps_df = play_store_data[play_store_data['Type'] == 'Paid']

# %%
earning_df = Paid_Apps_df[['App', 'Installs', 'Price']]

# %%
earning_df['Earnings'] = earning_df['Installs'] * earning_df['Price'];
earning_df_sorted_by_Earnings = earning_df.sort_values(by='Earnings', ascending=False).head(50)
earning_df_sorted_by_Price = earning_df_sorted_by_Earnings.sort_values(by='Price', ascending=False)

# %%
# PLot a bar chart of earning at y and app names at x
plt.figure(figsize=(15,9))
plt.bar(earning_df_sorted_by_Price.App, earning_df_sorted_by_Price.Earnings, width=1.1,
        label=earning_df_sorted_by_Price.Earnings)
plt.xlabel("Apps")
plt.ylabel("Earnings")
plt.tick_params(rotation=90)
plt.title("Top Earning Apps");

# %% [markdown]
# # *Do price of the app effects the rating?

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.regplot(x="Price", y="Rating", data=play_store_data)
plt.title("Price VS Rating", size=20)
# Out:
# Text(0.5, 1.0, 'Price VS Rating')

# %% [markdown]
# Yes, as the price increases ratings received seems to decrease even below the average rating in the appstore.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project of analyzing play store applications, we have worked on several parameters which would help MNC to do well in launching their apps on the play store.
#
# In the initial phase, we focused more on the problem statements and data cleaning, in order to ensure that we give them the best results out of our analysis.
#
# MNC needs to focus more on:
#
# 1. Developing apps related to the least categories as they are not explored much. Like events and beauty.
# 2. Most of the apps are Free, so focusing on free app is more important.
# 3. Focusing more on content available for Everyone will increase the chances of getting the highest installs.
# 4. They need to focus on updating their apps regularly, so that it will attract more users.
# 5. They need to keep in mind that the sentiments of the user keep varying as they keep using the app, so they should focus more    on users needs and features.
